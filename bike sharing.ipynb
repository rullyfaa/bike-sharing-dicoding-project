# %% [markdown]
# ## PROJECT ANALYSIS DATA :  Bike Sharing Dataset

# %% [markdown]
# #### Nama              : Rully Fathu Arkan
# #### Email               : rully.fathu@gmail.com
# #### ID Dicoding    : 6RPN4LD78X2M

# %%
https://github.com/rullyfaa/bike-sharing-dicoding-project/blob/main/Bike-sharing-dataset/day.csv

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# ### 1. Durasi Rata-rata Peminjaman:
# Berapa rata-rata durasi peminjaman sepeda? Apakah ada perbedaan signifikan antara hari kerja dan akhir pekan?

# %% [markdown]
# ### 2. Pola Peminjaman pada Jam Tertentu:
#
# Apakah ada jam tertentu dalam sehari yang lebih populer untuk peminjaman sepeda?

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %%
day_df = pd.read_csv("https://raw.githubusercontent.com/rullyfaa/bike-sharing-dicoding-project/main/Bike-sharing-dataset/day.csv")

hour_df = pd.read_csv("https://raw.githubusercontent.com/rullyfaa/bike-sharing-dicoding-project/main/Bike-sharing-dataset/hour.csv")

# %%
day_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
day_df.shape

# %%
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
day_df.info() #terdapat data type yang tidak akurat
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print ("jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# jumlah duplikasi:  0

# %%
day_df.describe()
# Out:
#        season          yr     cnt        hour
# count   731.0  731.000000   731.0  731.000000
# mean      2.0    0.500684  4504.0   11.417237
# std       0.0    0.500342     0.0    6.918087
# min       2.0    0.000000  4504.0    0.000000
# 25%       2.0    0.000000  4504.0    5.000000
# 50%       2.0    1.000000  4504.0   11.000000
# 75%       2.0    1.000000  4504.0   17.000000
# max       2.0    1.000000  4504.0   23.000000

# %%
hour_df.info() #terdapat data type yang tidak akurat
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("jumlah duplikasi :", hour_df.duplicated().sum())
# Out:
# jumlah duplikasi : 0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ## Data Cleaning

# %%
#mengganti type data pada dteday day_df dan hour_df menjadi datetime.

# %%
datetime_columns = ["dteday"]
for columns in datetime_columns:
    day_df[columns] = pd.to_datetime(day_df[columns])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   instant   731 non-null    object
#  1   dteday    731 non-null    datetime64[ns]
#  2   season    731 non-null    int64
#  3   yr        731 non-null    int64
#  4   cnt       731 non-null    int64
#  5   hour      731 non-null    int64
#  6   day_type  731 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 40.1+ KB

# %%
datetime_columns = ["dteday"]
for columns in datetime_columns:
    hour_df[columns] = pd.to_datetime(hour_df[columns])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
day_df.describe(include="all")
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  2011-01-01         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# ...

# %% [markdown]
# #### Berapa rata-rata durasi peminjaman sepeda? Apakah ada perbedaan signifikan antara hari kerja dan akhir pekan?

# %%
day_df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# ...

# %%
day_df.groupby("mnth").agg({
    'casual' : 'sum',
    'registered' : 'sum'
}).sort_values(by=['casual', 'registered'], ascending = False)
# Out:
#       casual  registered
# mnth
# 7      78157      266791
# 5      75285      256401
# 6      73906      272436
# 8      72039      279155
# 9      70323      275668
# 4      60802      208292
# 10     59760      262592
# 3      44444      184476
# 11     36603      218228
# 12     21693      189343
# 2      14963      136389
# 1      12042      122891

# %%
day_df = pd.DataFrame(day_df)

# Membuat kolom baru untuk menandai hari kerja (workingday)
day_df['day_type'] = day_df['yr'].apply(lambda x: 'Weekend' if x == 0 else 'Working Day')

# Menghitung rata-rata durasi peminjaman untuk hari kerja dan akhir pekan
average_duration_weekend = day_df[day_df['day_type'] == 'Weekend']['cnt'].mean()
average_duration_workingday = day_df[day_df['day_type'] == 'Working Day']['cnt'].mean()

print(f"Rata-rata durasi peminjaman pada akhir pekan: {average_duration_weekend}")
print(f"Rata-rata durasi peminjaman pada hari kerja: {average_duration_workingday}")
# Out:
# Rata-rata durasi peminjaman pada akhir pekan: 3405.7616438356163
# Rata-rata durasi peminjaman pada hari kerja: 5599.934426229508

# %% [markdown]
# jumlah peminjam sepeda pada hari kerja lebih banyak dari pada akhir pekan.

# %% [markdown]
# #### Apakah ada jam tertentu dalam sehari yang lebih populer untuk peminjaman sepeda?

# %%
hour_df.describe(include="all")
# Out:
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2011-01-01           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
#                   hr       holiday       weekday    workingday    weathersit  \
# ...

# %%
hour_df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# ...

# %%
hour_df.groupby("hr").agg({
    "instant" : "nunique",
    "casual" : "mean",
    "registered" : "mean",
    "cnt" : "mean",
    
}).sort_values(by = ["casual", "registered", "cnt"])
# Out:
#     instant     casual  registered         cnt
# hr
# 4       697   1.253945    5.098996    6.352941
# 5       717   1.411437   18.478382   19.889819
# 3       697   2.715925    9.011478   11.727403
# 6       725   4.161379   71.882759   76.044138
# 2       715   4.772028   18.097902   22.869930
# 1       724   6.504144   26.871547   33.375691
# 0       726  10.158402   43.739669   53.898072
# 7       727  11.055021  201.009629  212.064649
# 23      728  15.199176   72.631868   87.831044
# 8       727  21.679505  337.331499  359.011004
# 22      728  22.252747  109.082418  131.335165
# 21      728  28.255495  144.059066  172.314560
# 9       727  30.891334  188.418157  219.309491
# 20      728  36.233516  189.796703  226.030220
# 10      727  46.477304  127.191197  173.668501
# 19      728  48.770604  262.752747  311.523352
# 11      727  59.540578  148.602476  208.143054
# 18      728  61.120879  364.390110  425.510989
# 12      728  68.293956  185.021978  253.315934
# ...

# %% [markdown]
# Dari informasi tersebut bisa disimpulkan baik user casual maupun user terdaftar cenderung meminjam sepeda pada jam 14.00 atau jam 2 siang. namun informasi tersebut susah dipahami alangkah lebih baik kita membuat fitur baru yaitu time_category yang mengelompokkan jam-jam tertentu menjadi satu kategori waktu.

# %%
def kategori_waktu(jam):
    if jam >= 6 and jam <12:
        jam = 'morning'
    elif jam >= 12 and jam <14:
        jam = 'noon'
    elif jam >= 14 and jam <18:
        jam = 'evening'
    elif jam >= 18 and jam <21:
        jam = 'evening'
    else:
        jam = 'night'
    
    return jam

hour_df['time_category'] = hour_df['hr'].apply(kategori_waktu)

# %%
hour_df [['hr', 'time_category']]
# Out:
#        hr time_category
# 0       0         night
# 1       1         night
# 2       2         night
# 3       3         night
# 4       4         night
# ...    ..           ...
# 17374  19       evening
# 17375  20       evening
# 17376  21         night
# 17377  22         night
# 17378  23         night
#
# [17379 rows x 2 columns]

# %% [markdown]
# Selanjutnya, kita bisa mellakukan analisis rata-rata jumlah peminjam sepeda pada kategori waktu tertentu.

# %%
hour_df.groupby(by = 'time_category').agg({
    'instant' : 'nunique',
    'casual' : 'mean',
    'registered' : 'mean',
    'cnt' : 'mean'
}).sort_values(by = ['casual', 'registered', 'cnt' ], ascending=False)
# Out:
#                instant     casual  registered         cnt
# time_category
# noon              1457  70.302677  183.185999  253.488675
# evening           5102  63.529596  254.878871  318.408467
# morning           4360  28.978899  179.121789  208.100688
# night             6460  10.388545   50.216254   60.604799

# %% [markdown]
# jadi rata rata jumlah peminjam sepeda pada kategori waktu yang paling banyak yaitu di waktu sore hari dengan jumlah 318.408467

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# #### Apakah ada perbedaan jumlah total user yang signifikan antara hari libur dan bukan hari libur?

# %% [markdown]
# kita perlu membuat sebuah dataframe baru yang memuat rata-rata jumlah peminjam sepeda dari dua jenis user, yaitu casual user dan registered user, pada dua kondisi waktu, yakni hari libur dan hari biasa (non libur). alasan menggunakan parameter statistik rata-rata adalah dikarenakan jumlah hari biasa (non-libur) selalu lebih banyak dengan hari libur.

# %%
mean_user_holiday = day_df.groupby(by = 'holiday').agg ({
    'instant' : 'nunique',
    'casual' : 'mean',
    'registered' : 'mean',
    'cnt' : 'mean'
})

# %%
mean_user_holiday
# Out:
#          instant       casual   registered          cnt
# holiday
# 0            710   841.771831  3685.332394  4527.104225
# 1             21  1064.714286  2670.285714  3735.000000

# %%
hari_libur = mean_user_holiday.index
jumlah_hari_libur = mean_user_holiday['instant']
plt.xticks(hari_libur, ['Non-Holiday', 'Holiday'])
labels = ['bukan hari libur', 'hari libur']
plt.bar(hari_libur, jumlah_hari_libur)

for i, v in enumerate(jumlah_hari_libur):
    plt.text(i, v, str(v), ha='center', va='bottom')


plt.xlabel('Kategori Hari Libur')
plt.ylabel('Jumlah Hari Libur')
plt.title('Jumlah Hari Libur vs Bukan Hari Libur')

plt.show()

# %%
casual = mean_user_holiday['casual']
registered = mean_user_holiday['registered']
hari_libur = mean_user_holiday.index


plt.xticks(hari_libur, ['Non-Holiday', 'Holiday'])
plt.bar(hari_libur, casual, label='Casual Users')
plt.bar(hari_libur, registered, bottom=casual, label='Registered Users')
plt.xlabel('hari_libur')
plt.ylabel('Number of Users')
plt.legend()
plt.title('Casual and Registered Holiday vs not Holiday')
plt.show()

# %% [markdown]
# total seluruh user cenderung meminjam sepeda pada hari biasa (non-libur) namun terdapat informasi menarik yaitu casual user lebih banyak meminjam sepeda pada hari libur.

# %% [markdown]
# #### apakah user lebih banyak meminjam sepeda di jam tertentu?

# %%
users_per_time = hour_df.groupby(by = 'time_category').agg ({
    'casual' : 'mean',
    'registered' : 'mean'
}).sort_values(by = ['casual', 'registered'])

# %%
users_per_time
# Out:
#                   casual  registered
# time_category
# night          10.388545   50.216254
# morning        28.978899  179.121789
# evening        63.529596  254.878871
# noon           70.302677  183.185999

# %%
casual = users_per_time['casual']
registered = users_per_time['registered']
time_category = users_per_time.index

plt.bar(time_category, casual, label='Casual Users')
plt.bar(time_category, registered, bottom=casual, label='Registered Users')
plt.xlabel('time_category')
plt.ylabel('Number of Users')
plt.legend()
plt.title('Casual and Registered Holiday vs not Holiday')
plt.show()

# %% [markdown]
# Dari hasil visualisasi tersebut dapat disimpulkan bahwa casual user lebih cenderung meminjam sepeda pada sore hari sedangkan registered user cenderung meminjam sepeda pada sore hari Sebaliknya, kategori malam hari memiliki jumlah casual user dan registered user yang paling rendah.

# %%
rfm_df = hour_df.groupby("instant").agg({
    "dteday" : "max",
    "cnt" : "sum",
    "instant": "nunique"
}).rename(columns={"instant" : "frequency", "cnt" : "monetary"})

# %%
max_date = hour_df["dteday"].max()
rfm_df["recency"] = (max_date - rfm_df["dteday"]).dt.days

# %%
rfm_df
# Out:
#             dteday  monetary  frequency  recency
# instant
# 1       2011-01-01        16          1      730
# 2       2011-01-01        40          1      730
# 3       2011-01-01        32          1      730
# 4       2011-01-01        13          1      730
# 5       2011-01-01         1          1      730
# ...            ...       ...        ...      ...
# 17375   2012-12-31       119          1        0
# 17376   2012-12-31        89          1        0
# 17377   2012-12-31        90          1        0
# 17378   2012-12-31        61          1        0
# 17379   2012-12-31        49          1        0
#
# [17379 rows x 4 columns]

# %%
fig, axes = plt.subplots(1, 3,figsize=(15, 5))

sns.histplot(rfm_df['recency'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Recency')

# Frequency
sns.histplot(rfm_df['frequency'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Frequency')

# Monetary
sns.histplot(rfm_df['monetary'], bins=20, kde=True, ax=axes[2])
axes[2].set_title('Monetary')

# Show plots
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Berapa rata-rata durasi peminjaman sepeda? Apakah ada perbedaan signifikan antara hari kerja dan akhir pekan?
#
# Rata-rata durasi peminjaman pada akhir pekan: 3405.
# Rata-rata durasi peminjaman pada hari kerja: 5599.
# jumlah peminjam sepeda pada hari kerja lebih banyak dari pada akhir pekan.

# %% [markdown]
# ### Apakah ada jam tertentu dalam sehari yang lebih populer untuk peminjaman sepeda?

# %% [markdown]
# casual user lebih cenderung meminjam sepeda pada sore hari sedangkan registered user cenderung meminjam sepeda pada sore hari Sebaliknya, kategori malam hari memiliki jumlah casual user dan registered user yang paling rendah.

# %%
day_df.to_csv('day_df.csv')
hour_df.to_csv('hour_df.csv')
